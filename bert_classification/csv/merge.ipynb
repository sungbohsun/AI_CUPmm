# %%
from google.colab import drive
drive.mount('/content/drive')
dataPath = '/content/drive/My Drive/Colab Notebooks/AI_CUP/'#bert_classification'
import os 
os.chdir(dataPath)
os.listdir()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ['資料集說明.docx',
#  '.ipynb_checkpoints',
#  'selenium',
#  'scrapy',
#  'bert_classification',
#  'bert_NER']

# %%
import pandas as pd
import glob

path = r'scrapy' # use your path
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

frame = pd.concat(li, axis=0, ignore_index=True)
df_scrapy = frame.dropna()

# %%
df = pd.read_csv('selenium/data_selenium.csv')
df = df.rename(columns={"news_url": "url"})

# %%
res = pd.merge(df,df_scrapy, on='url')
res.sample(5)
res.to_csv('bert_classification/csv/res.csv')

# %%
len(res[res['name'].isna()]),len(res[~res['name'].isna()])
# Out:
# (1755, 562)

# %%
doc_len = []
for i in range(len(res)):
  doc_len.append(len(res['doc'][i]))

# %%
doc_len.sort()

# %%
x = np.arange(len(res))

# %%
 import matplotlib.pyplot as plt
 plt.bar(np.arange(len(res)),doc_len)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9eee48fcd94c> in <module>()
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.hist(np.arange(len(res)),doc_len)
#
# NameError: name 'np' is not defined

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot(doc_len, hist=True, kde=False, color = 'blue',
             hist_kws={'edgecolor':'black'})

plt.xlim(0, 5000)
# Out:
# (0.0, 5000.0)

# %%
res
# Out:
#       Unnamed: 0  ...                                                doc
# 0              0  ...  中國電器公司董事長周麗真（左）被控勾結前總經理張志偉，利用海外子公司掏空中電。（資料照，記者...
# 1              1  ...  記者楊佩琪／台北報導,以「東亞照明」稱霸台灣照明市場的中國電器(1611)，董事長周麗真、前...
# 2              2  ...  鯉魚潭水庫。（資料照）,〔記者張文川／台北報導〕12年前爆發的花蓮縣壽豐鄉鯉魚潭風景區的「綠...
# 3              3  ...  記者吳銘峯／台北報導,花蓮縣壽豐鄉鯉魚潭風景區「綠湖國際大飯店開發計畫」官商勾結弊案，當時王...
# 4              7  ...  記者孫于珊／台北報導,被稱為「理財專家」的廖泰宇，2018年因馬勝金融集團吸金案一審被判刑8...
# ...          ...  ...                                                ...
# 2312        5637  ...  \n    全文朗讀\n  ,\n    00:00,被各種數據與會議淹沒的一週結束了，主要...
# 2313        5639  ...  37歲的「情色教主」雪碧（方祺媛）傳出極祕生產，目前正在月子中心調養，驚人的是，雪碧從懷孕到...
# 2314        5641  ...  \r\n,特首林鄭月娥4日宣布撤回逃犯條例修訂，示威者斥為「太遲太少」，「一碗水救不了森林大...
# 2315        5642  ...  OTC 持續向上推進，今天的好消息是，最快在兩週內，美方就會對美國企業批准發放許可，重啟對華...
# 2316        5645  ...  全球投資市場操作難度升高，群益期貨副總經理黃維本建議，投資人應該嚴格控管風險，操作股票期貨的...
#
# [2317 rows x 8 columns]
